# %%
import fastf1

# %%
# session = fastf1.get_session(2024, 'São Paulo Grand Prix', 'R')
session = fastf1.get_session(2024, 'Saudi Arabian Grand Prix', 'R')
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (101.87 MB) /Users/seansica/Library/Caches/fastf1

# %%
session.load()
# Out:
# core           INFO 	Loading data for Saudi Arabian Grand Prix - Race [v3.5.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '11', '16', '81', '14', '63', '38', '4', '44', '27', '23', '20', '31', '2', '22', '3', '77', '24', '18', '10']

# %%
session.get_circuit_info().marshal_lights
# Out:
#               X             Y  Number Letter       Angle     Distance
# 0  -1291.000004    216.000097       1        -158.979079  6100.698213
# 1  -2537.846699   3956.515829       2          15.229728   388.053394
# 2  -3401.121493   5738.370319       3         -13.270785   628.917504
# 3  -3624.587265   8839.184186       4           3.364503   938.334674
# 4  -4597.691801  10309.212952       5           4.005263  1150.448414
# 5  -4785.041071  12803.027227       6        -123.405456  1407.373544
# 6  -3874.724457  15686.481246       7          -9.543217  1749.989998
# 7  -3556.468928  20484.471647       8           5.112440  2236.940593
# 8  -4754.602197  20501.212821       9          16.072863  2557.743380
# 9  -4242.566545  17649.376805      10         -17.962137  2865.763366
# 10 -5789.441133  14647.196543      11        -182.204630  3207.048451
# 11 -5100.740512  11780.818323      12          13.963294  3496.111973
# ...

# %%
session.get_circuit_info().corners
# Out:
#               X             Y  Number Letter       Angle     Distance
# 0  -2908.523056   4757.490498       1          69.136629   481.188089
# 1  -3463.171720   4834.551790       2          40.811417   537.179965
# 2  -3333.324770   6205.801601       3          -3.557132   690.158196
# 3  -3726.875378   9192.730297       4          47.148852   993.001772
# 4  -4503.338061   9863.121848       5          22.803467  1094.773379
# 5  -4285.277170  11311.588157       6         -17.739135  1241.799145
# 6  -4405.375789  12447.507360       7          22.025440  1355.308140
# 7  -4926.652429  12948.264922       8          28.393642  1424.050542
# 8  -4851.685766  14451.239276       9         141.246600  1572.992993
# 9  -4049.885092  15075.214008      10         -33.919414  1688.255570
# 10 -3793.615593  16049.942226      11         -14.634055  1798.892257
# 11 -3573.734876  16904.965130      12          -9.142795  1895.412687
# ...

# %%
session.results
# Out:
#    DriverNumber BroadcastName Abbreviation         DriverId  \
# 33           33  M VERSTAPPEN          VER   max_verstappen
# 44           44    L HAMILTON          HAM         hamilton
# 77           77      V BOTTAS          BOT           bottas
# 16           16     C LECLERC          LEC          leclerc
# 10           10       P GASLY          GAS            gasly
# 3             3   D RICCIARDO          RIC        ricciardo
# 4             4      L NORRIS          NOR           norris
# 55           55       C SAINZ          SAI            sainz
# 14           14      F ALONSO          ALO           alonso
# 18           18      L STROLL          STR           stroll
# 11           11       S PEREZ          PER            perez
# 99           99  A GIOVINAZZI          GIO       giovinazzi
# 22           22     Y TSUNODA          TSU          tsunoda
# 7             7   K RAIKKONEN          RAI        raikkonen
# 63           63     G RUSSELL          RUS          russell
# ...

# %%
session.track_status
# Out:
#                      Time Status      Message
# 0         0 days 00:00:00      1     AllClear
# 1  0 days 00:52:58.758000      2       Yellow
# 2  0 days 00:58:32.359000      1     AllClear
# 3  0 days 01:13:10.258000      2       Yellow
# 4  0 days 01:13:19.484000      1     AllClear
# 5  0 days 01:17:25.352000      2       Yellow
# 6  0 days 01:17:28.803000      1     AllClear
# 7  0 days 01:27:37.971000      2       Yellow
# 8  0 days 01:27:48.625000      1     AllClear
# 9  0 days 01:47:45.888000      2       Yellow
# 10 0 days 01:47:49.810000      1     AllClear
# 11 0 days 01:49:38.987000      2       Yellow
# 12 0 days 01:50:18.848000      6  VSCDeployed
# 13 0 days 01:51:47.994000      7    VSCEnding
# 14 0 days 01:52:01.710000      1     AllClear
# 15 0 days 01:54:50.200000      4   SCDeployed
# 16 0 days 01:59:19.333000      5          Red
# 17 0 days 02:23:12.325000      1     AllClear
# 18 0 days 02:26:20.605000      2       Yellow
# ...

# %%
laps = session.laps

laps_ver = laps[laps['Driver']=='VER']

laps_ver.head()
# Out:
#                     Time Driver DriverNumber                LapTime  \
# 0 0 days 00:24:04.661000    VER           33                    NaT
# 1 0 days 00:25:35.160000    VER           33 0 days 00:01:30.499000
# 2 0 days 00:27:25.520000    VER           33 0 days 00:01:50.360000
# 3 0 days 00:44:22.361000    VER           33                    NaT
# 4 0 days 00:45:52.679000    VER           33 0 days 00:01:30.318000
#
#    LapNumber  Stint             PitOutTime              PitInTime  \
# 0        1.0    1.0 0 days 00:21:18.434000                    NaT
# 1        2.0    1.0                    NaT                    NaT
# 2        3.0    1.0                    NaT 0 days 00:27:23.844000
# 3        4.0    2.0 0 days 00:42:21.384000                    NaT
# 4        5.0    2.0                    NaT                    NaT
#
#              Sector1Time            Sector2Time  ... FreshTyre  \
# 0                    NaT 0 days 00:01:24.332000  ...      True
# ...

# %%
laps_ver_telemetry = laps_ver.get_telemetry()

display(laps_ver_telemetry.head())
display(len(laps_ver_telemetry))
# Out:
#                      Date            SessionTime DriverAhead  \
# 2 2021-03-27 15:06:18.819 0 days 00:21:18.434000
# 3 2021-03-27 15:06:18.867 0 days 00:21:18.482000
# 4 2021-03-27 15:06:18.963 0 days 00:21:18.578000
# 5 2021-03-27 15:06:19.147 0 days 00:21:18.762000          18
# 6 2021-03-27 15:06:19.183 0 days 00:21:18.798000          18
#
#    DistanceToDriverAhead                   Time      RPM      Speed  nGear  \
# 2             102.952222        0 days 00:00:00  7386.00  81.600000      2
# 3             102.952222 0 days 00:00:00.048000  7455.00  82.000000      2
# 4             102.952222 0 days 00:00:00.144000  7603.80  83.714286      2
# 5             102.952222 0 days 00:00:00.328000  7889.00  87.000000      2
# 6             103.142222 0 days 00:00:00.364000  7975.85  87.750000      2
#
#    Throttle  Brake  DRS         Source  Distance  RelativeDistance   Status  \
# 2      27.4  False    8  interpolation  0.081425          0.000001  OnTrack
# ...

# %%
laps_ver.iloc[0].get_car_data()
# Out:
#                        Date      RPM  Speed  nGear  Throttle  Brake  DRS  \
# 0   2021-03-27 15:06:18.867   7455.0   82.0      2      25.0  False    8
# 1   2021-03-27 15:06:19.147   7889.0   87.0      2      32.0  False    8
# 2   2021-03-27 15:06:19.387   8468.0   92.0      2      42.0  False    8
# 3   2021-03-27 15:06:19.627   8970.0  100.0      2      47.0  False    8
# 4   2021-03-27 15:06:19.867   9652.0  106.0      2      52.0  False    8
# ..                      ...      ...    ...    ...       ...    ...  ...
# 685 2021-03-27 15:09:03.947  11463.0  284.0      7     100.0  False   12
# 686 2021-03-27 15:09:04.187  11637.0  289.0      7     100.0  False   12
# 687 2021-03-27 15:09:04.427  11752.0  293.0      7     100.0  False   12
# 688 2021-03-27 15:09:04.667  11159.0  295.0      7     100.0  False   12
# 689 2021-03-27 15:09:04.907  10748.0  297.0      8     100.0  False   12
#
#     Source                   Time            SessionTime
# ...

# %%
laps_ver.iloc[1].get_car_data()
# Out:
#                        Date      RPM  Speed  nGear  Throttle  Brake  DRS  \
# 0   2021-03-27 15:09:05.147  10778.0  299.0      8     100.0  False   12
# 1   2021-03-27 15:09:05.387  10843.0  301.0      8     100.0  False   12
# 2   2021-03-27 15:09:05.667  11056.0  304.0      8     100.0  False   12
# 3   2021-03-27 15:09:05.907  11076.0  305.0      8     100.0  False   12
# 4   2021-03-27 15:09:06.147  11100.0  307.0      8     100.0  False   12
# ..                      ...      ...    ...    ...       ...    ...  ...
# 371 2021-03-27 15:10:34.467  11466.0  284.0      7     100.0  False   12
# 372 2021-03-27 15:10:34.707  11482.0  285.0      7     100.0  False   12
# 373 2021-03-27 15:10:34.946  11587.0  289.0      7     100.0  False   12
# 374 2021-03-27 15:10:35.147  11640.0  290.0      7     100.0  False   12
# 375 2021-03-27 15:10:35.387  11817.0  292.0      7     100.0  False   12
#
#     Source                   Time            SessionTime
# ...

# %%
laps_ver.iloc[1].get_pos_data()
# Out:
#                        Date   Status      X       Y      Z Source  \
# 0   2021-03-27 15:09:05.224  OnTrack -377.0  1348.0 -159.0    pos
# 1   2021-03-27 15:09:05.444  OnTrack -368.0  1532.0 -158.0    pos
# 2   2021-03-27 15:09:05.664  OnTrack -360.0  1716.0 -159.0    pos
# 3   2021-03-27 15:09:05.884  OnTrack -351.0  1902.0 -159.0    pos
# 4   2021-03-27 15:09:06.104  OnTrack -344.0  2088.0 -159.0    pos
# ..                      ...      ...    ...     ...    ...    ...
# 407 2021-03-27 15:10:34.503  OnTrack -425.0   390.0 -159.0    pos
# 408 2021-03-27 15:10:34.723  OnTrack -416.0   564.0 -159.0    pos
# 409 2021-03-27 15:10:34.943  OnTrack -407.0   740.0 -159.0    pos
# 410 2021-03-27 15:10:35.163  OnTrack -399.0   895.0 -159.0    pos
# 411 2021-03-27 15:10:35.383  OnTrack -390.0  1074.0 -159.0    pos
#
#                       Time            SessionTime
# 0   0 days 00:00:00.178000 0 days 00:24:04.839000
# 1   0 days 00:00:00.398000 0 days 00:24:05.059000
# ...

# %%
session.track_status
# Out:
#                     Time Status     Message
# 0        0 days 00:00:00      2      Yellow
# 1 0 days 00:08:45.692000      1    AllClear
# 2 0 days 01:09:15.917000      2      Yellow
# 3 0 days 01:09:49.924000      4  SCDeployed
# 4 0 days 01:16:35.527000      1    AllClear
